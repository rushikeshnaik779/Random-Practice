# %% [markdown]
# <a href="https://colab.research.google.com/github/rushikeshnaik779/Random-Practice/blob/main/Restaurant_Revenue_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd 
import os

# %%
from google.colab import drive 
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import os 
os.environ['KAGGLE_CONFIG_DIR'] = '/content/gdrive/My Drive/Kaggle'

# %%
# %cd /content/gdrive/My Drive/Kaggle
# Out:
# /content/gdrive/My Drive/Kaggle

# %%
# !kaggle competitions download -c restaurant-revenue-prediction
# Out:
# ...
#   0% 0.00/4.54k [00:00<?, ?B/s]
# 100% 4.54k/4.54k [00:00<00:00, 626kB/s]
# ...
#   0% 0.00/231k [00:00<?, ?B/s]
# 100% 231k/231k [00:00<00:00, 14.8MB/s]
# ...
#   0% 0.00/2.45M [00:00<?, ?B/s]
# 100% 2.45M/2.45M [00:00<00:00, 81.1MB/s]

# %%
# !unzip \*.zip && rm *.zip
# Out:
# Archive:  train.csv.zip
# replace train.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: train.csv
#
# Archive:  sampleSubmission.csv.zip
#   inflating: sampleSubmission.csv
#
# Archive:  test.csv.zip
# replace test.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: test.csv
#
# 3 archives were successfully processed.

# %%
data = pd.read_csv('./train.csv')
data.head()
# Out:
#    Id   Open Date        City  City Group Type  ...  P34  P35  P36  P37    revenue
# 0   0  07/17/1999    İstanbul  Big Cities   IL  ...    5    4    3    4  5653753.0
# 1   1  02/14/2008      Ankara  Big Cities   FC  ...    0    0    0    0  6923131.0
# 2   2  03/09/2013  Diyarbakır       Other   IL  ...    0    0    0    0  2055379.0
# 3   3  02/02/2012       Tokat       Other   IL  ...   18   12   12    6  2675511.0
# 4   4  05/09/2009   Gaziantep       Other   IL  ...    3    4    3    3  4316715.0
#
# [5 rows x 43 columns]

# %%
import matplotlib.pyplot as plt 

plt.figure(figsize = (30, 30))

import seaborn as sns
sns.heatmap(data.corr(), annot=True, cmap='Blues')
